# %% [markdown]
# **1. A die is rolled. What is the probability of getting:**
#
# **(a) An even number**
#
# **(b) A number greater than 4 **
#
# -a The probability of getting an even no. is 1/2
#
# -b The probability of getting a number greater than 4= 1/3
#
# **2.  In a class of 50 students:**
#
# **20 like Mathematics (M)**
#
# **15 like Science (S)**
#
# **5 like both subjects**
#
# **What is the probability that a student chosen at random likes Mathematics or Science?**
#
# - The probability of  student choosen at random like mathematics or science =20+15-5=30 and 30/50=**3/5**
#
# **3.  A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability**
# **that the next ball is also red (without replacement)?**
#
# - The probability of drawing next ball red is 2/4=**1/2**
#
# **4. The population of a school is divided into 60% boys and 40% girls. If you want equal representation**
# **of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling? why?**
#
# Here we will use stratified sampling because here in stratified sampling involves dividing the entire population into two group known as strata and in this case boys and girls and it allow the researcher to specifically select a set number from each group since the goal is equal reprentation and hence it will carry more precision,
#
# **5. The average height of 1000 students = 160 cm. A sample of 100 students shows an average height**
# **= 158 cm.**
#
# **Find the sampling error**
#
# Sample error = population mean -sample mean and hence
#
# sample error will be 160-158=2 cm
#
# **6. The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what**
# **is the standard error of the mean (SEM)?**
#
# **7.  In a group of 100 students:**
#
# **40 like Cricket (C)**
#
# **30 like Football (F)**
#
# **10 like both Cricket and Football**
#
# **Find the probability that a student likes at least one sport.**
#
# - The probability of getting student who likes  at least one sports is = 40+30-10= 60 hense probability =60/100=3/5
#
# **8.  From a deck of 52 cards, two cards are drawn without replacement. What is the probability that**
# **both are Aces?**
#
# when one card is drawn probablity of ace is 4/52=1/13
#
# and when other caerd is drawn without replacement then probability is 3/51
# hence for both it is 1/13*4/51= **1/221**
#
# **9. A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the**
# **probability that all are non-defective?**
#
#  - for choosing a defective bulb the probability is 2/100=0.02
#
#   hense for choosing non defective bulb is 1-0.02=0.98
#    hense for 5 bulbs the probability is (0.98)^5 means 0.98 multiplied by five times = 0.9039
#
#    **10. Differentiate between discrete and continuous random variables with examples.**
#
#    - the best difference is the outcomes of discrete random variable is in whole number ( for ex- the number of car crossing per hour)
#
#    while
#
#    the continues random variable the outcome is always in decimal ( for ex- height of the whole class and even temperature of the june month per day
